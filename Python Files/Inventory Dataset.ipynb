# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataCoSupplyChainDataset.csv", encoding = 'cp1252')

# %%
df = df.rename(columns = {'Product Card Id': 'Product ID', 'order date (DateOrders)': 'order_date', 
                          'Order Item Quantity': 'Total Units Sold', 'Sales': 'Total Sales', 'Order Profit Per Order': 'Total Profit'})

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format = '%m/%d/%Y %H:%M')
df['Date'] = df['order_date'].dt.to_period('M').dt.to_timestamp()

# %%
first_appear = (df.groupby('Product ID')['Date'].min().reset_index(name = 'first_date'))
max_date = df['Date'].max()

rows = []
for _, r in first_appear.iterrows():
    pid   = r['Product ID']
    start = r['first_date']
    # all month-starts from first appearance through max_date
    for dt in pd.date_range(start = start, end = max_date, freq = 'MS'):
        rows.append({'Product ID': pid, 'Date': dt})

grid = pd.DataFrame(rows)

# %%
prod_master = (df[['Product ID', 'Product Name', 'Department Id', 'Category Id', 'Category Name', 'Product Price']]
    .drop_duplicates(subset = 'Product ID')
)

# %%
agg = (df.groupby(['Date', 'Product ID']).agg({'Total Units Sold': 'sum', 'Total Sales': 'sum', 'Total Profit': 'sum'}).reset_index())

# %%
full = (pd.merge(grid, agg, on = ['Product ID', 'Date'], how = 'left').fillna({'Total Units Sold': 0, 'Total Sales': 0.0, 'Total Profit':0.0}))

# %%
inv = full.merge(prod_master, on = 'Product ID', how = 'left')

# %%
rng = np.random.default_rng(seed = 42)
inv['Competitor Pricing'] = (inv['Product Price'] * rng.uniform(0.9, 1.1, size = len(inv))).round(2)
inv['Cost to Company'] = (inv['Product Price'] * rng.uniform(0.6, 0.8, size = len(inv))).round(2)

# %%
inv['month'] = inv['Date'].dt.month
inv['quarter'] = inv['Date'].dt.quarter
inv['is_month_start'] = inv['Date'].dt.is_month_start
inv['is_month_end'] = inv['Date'].dt.is_month_end

# %%
inv = inv.sort_values(['Product ID','Date']).reset_index(drop = True)
inv['seasonal_naive'] = inv.groupby('Product ID')['Total Units Sold'].shift(12)
inv['rolling_ma3'] = inv.groupby('Product ID')['Total Units Sold']\
                             .transform(lambda x: x.shift(1)
                                             .rolling(window = 3, min_periods = 1)
                                             .mean())

# %%
inv['Demand Forecast'] = ((0.2 * inv['seasonal_naive'] + 0.8 * inv['rolling_ma3']).round().fillna(inv['rolling_ma3']).fillna(0).round().astype(int))
inv.drop(columns = ['seasonal_naive', 'rolling_ma3'], inplace = True)

# %%
init_frac, order_frac = 1.2, 0.8

def flow_calc(group):
    group = group.sort_values('Date').copy()
    inv_lvls, units_ord, tot_inv = [], [], []
    prev_tot = None

    for _, row in group.iterrows():
        sold = row['Total Units Sold']
        fcst = row['Demand Forecast']

        if prev_tot is None:
            # init based on actual sales (never zero if sold>0)
            inv_lvl = int(init_frac * sold)
            prev_tot = inv_lvl
        else:
            inv_lvl = prev_tot

        # base order from forecast
        base_uo = int(order_frac * fcst)
        # bump up order if base_uo + on-hand < sold, to avoid negative
        uo = base_uo if (prev_tot + base_uo) >= sold else (sold - prev_tot)

        ti = prev_tot + uo - sold

        inv_lvls.append(inv_lvl)
        units_ord.append(uo)
        tot_inv.append(ti)

        prev_tot = ti

    group['Inventory Level'] = inv_lvls
    group['Units Ordered']    = units_ord
    group['Total Inventory']  = tot_inv
    return group

inv = (
    inv
    .groupby('Product ID', group_keys=False)
    .apply(flow_calc)
    .reset_index(drop=True)
)
# Out:
# C:\Users\neel9\AppData\Local\Temp\ipykernel_2612\2008329361.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   inv

# %%
# 13) Reorder columns and export
final_cols = [
    'Date', 'Product ID', 'Product Name', 'Department Id', 'Category Id',
    'Category Name', 'Inventory Level', 'Total Units Sold', 'Total Sales',
    'Total Profit', 'Units Ordered', 'Demand Forecast', 'Product Price',
    'Competitor Pricing', 'Cost to Company', 'Total Inventory',
    'month', 'quarter', 'is_month_start', 'is_month_end'
]
inventory_df = inv[final_cols]

# %%
inventory_df
# Out:
#            Date  Product ID                             Product Name  \
# 0    2017-04-01          19  Nike Men's Fingertrap Max Training Shoe
# 1    2017-05-01          19  Nike Men's Fingertrap Max Training Shoe
# 2    2017-06-01          19  Nike Men's Fingertrap Max Training Shoe
# 3    2017-07-01          19  Nike Men's Fingertrap Max Training Shoe
# 4    2017-08-01          19  Nike Men's Fingertrap Max Training Shoe
# ...         ...         ...                                      ...
# 2445 2018-01-01        1361                                    Toys
# 2446 2017-12-01        1362                     Fighting video games
# 2447 2018-01-01        1362                     Fighting video games
# 2448 2017-12-01        1363                           Summer dresses
# 2449 2018-01-01        1363                           Summer dresses
#
#       Department Id  Category Id     Category Name  Inventory Level  \
# 0                 2            2            Soccer              2.0
# 1                 2            2            Soccer              0.0
# 2                 2            2            Soccer              0.0
# 3                 2            2            Soccer              0.0
# 4                 2            2            Soccer              0.0
# ...             ...          ...               ...              ...
# 2445              7           74              Toys             50.0
# 2446              9           75       Video Games            273.0
# 2447              9           75       Video Games             45.0
# 2448              4           76  Women's Clothing            326.0
# 2449              4           76  Women's Clothing             54.0
#
#       Total Units Sold   Total Sales  Total Profit  Units Ordered  \
# 0                  2.0    249.979996    106.320000            0.0
# 1                 13.0   1624.869973    228.510005           13.0
# 2                 13.0   1624.869973    458.999994           13.0
# 3                 15.0   1874.849969    325.769995           15.0
# 4                 17.0   2124.829964   -194.960013           17.0
# ...                ...           ...           ...            ...
# 2445             276.0   3185.039989    443.520002          226.0
# 2446             228.0   9063.000000    750.370007            0.0
# 2447             610.0  24247.500000   1967.149990          565.0
# 2448             272.0  58703.041986   7927.739958            0.0
# 2449             378.0  81579.962759  11175.109972          324.0
#
#       Demand Forecast  Product Price  Competitor Pricing  Cost to Company  \
# 0                   0     124.989998              131.84            91.43
# 1                   2     124.989998              123.46            93.00
# 2                   8     124.989998              133.95            91.03
# 3                   9     124.989998              129.92            94.75
# 4                  14     124.989998              114.85            90.61
# ...               ...            ...                 ...              ...
# 2445              253      11.540000               11.71             8.03
# 2446                0      39.750000               36.17            25.61
# 2447              228      39.750000               38.99            27.88
# 2448                0     215.820007              219.40           167.86
# 2449              272     215.820007              219.50           163.69
#
#       Total Inventory  month  quarter  is_month_start  is_month_end
# 0                 0.0      4        2            True         False
# 1                 0.0      5        2            True         False
# 2                 0.0      6        2            True         False
# 3                 0.0      7        3            True         False
# 4                 0.0      8        3            True         False
# ...               ...    ...      ...             ...           ...
# 2445              0.0      1        1            True         False
# 2446             45.0     12        4            True         False
# 2447              0.0      1        1            True         False
# 2448             54.0     12        4            True         False
# 2449              0.0      1        1            True         False
#
# [2450 rows x 20 columns]

# %%
import numpy as np

inventory_df['Date'] = pd.to_datetime(inventory_df['Date'])
inventory_df = inventory_df.sort_values(['Product ID', 'Date']).reset_index(drop=True)

mask = inventory_df['Units Ordered'] == 0
inventory_df.loc[mask, 'Units Ordered'] = inventory_df.loc[mask, 'Total Units Sold'] * np.random.uniform(0.9, 1.1, size=mask.sum())

inventory_df['Units Ordered'] = inventory_df['Units Ordered'].round(0)

mask = inventory_df['Demand Forecast'] < inventory_df['Units Ordered']
inventory_df.loc[mask, 'Demand Forecast'] = inventory_df.loc[mask, 'Units Ordered'] * np.random.uniform(1.1, 1.5, size = mask.sum())

inventory_df['Demand Forecast'] = inventory_df['Demand Forecast'].round(0)

def update_inventory(group):
    group = group.sort_values('Date').copy()
    inv_lvls = []
    tot_inv = []
    prev_tot = 0
    for _, row in group.iterrows():
        inv_lvl = prev_tot + row['Demand Forecast']
        total_inventory = inv_lvl - row['Total Units Sold']
        inv_lvls.append(inv_lvl)
        tot_inv.append(total_inventory)
        prev_tot = total_inventory
    group['Inventory Level'] = [round(x, 0) for x in inv_lvls]
    group['Total Inventory'] = [round(x, 0) for x in tot_inv]
    return group

inventory_df = inventory_df.groupby('Product ID', group_keys=False).apply(update_inventory).reset_index(drop=True)
inventory_df
# Out:
# C:\Users\neel9\AppData\Local\Temp\ipykernel_2612\3499703856.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[2.65998745e+00 1.66112385e+01 1.90332643e+01 1.84146594e+01
#  2.18496668e+01 1.63443449e+01 8.07144454e+01 7.71052078e+01
#  6.51141552e+00 1.82444787e+01 1.63193730e+01 1.67615614e+01
#  2.59786707e+01 3.85814341e+01 3.68904193e+01 3.75533876e+01
#  4.72795862e+01 4.09569502e+01 5.47518198e+01 4.64240309e+01
#  6.45185939e+01 3.59245396e+01 4.80025768e+01 6.54318938e+01
#  5.98938587e+01 5.98260731e+01 4.09475307e+01 3.80290511e+01
#  5.14425719e+01 5.69793700e+01 5.87983305e+01 4.84180281e+01
#  4.56538628e+01 4.07417122e+01 3.65215220e+01 4.78715119e+01
#  3.33153690e+01 2.44787564e+00 1.10799415e+01 3.38699867e+01
#  1.52273683e+01 5.89342296e+01 5.09639282e+01 4.53971318e+01
#  4.24911167e+01 6.11540526e+01 5.36249261e+01 4.74021362e+01
#  3.24177860e+01 5.03869588e+01 4.34892169e+01 4.38586633e+01
#  6.16492433e+01 5.45120227e+01 5.65541249e+01 5.73437874e+01
#  5.16740488e+01 6.09933864e+01 4.47509091e+01 5.08845272e+01
#  7.80346866e+01 5.08554991e+01 6.24494521e+01 5.56621178e+01
#  4.88669355e+01 3.12877982e+01 6.57734198e+01 2.71695282e+01
#  6.29301805e+01 4.93415838e+01 5.11467061e+01 4.29981674e+01
#  4.42719136e+01 4.61511643e+01 7.15181245e+01 5.74694273e+01
#  4.38563947e+01 5.89528440e+01 6.00731103e+01 3.62500147e+01
#  3.60079023e+01 4.27814914e+01 5.02719869e+01 4.45527257e+01
#  6.95181040e+01 5.73050210e+01 5.09869041e+01 3.77598987e+01
#  3.42295420e+01 4.34036931e+01 8.49059044e+01 4.49977892e+01
#  5.40720077e+01 1.36310080e+03 1.83614042e+03 1.41353625e+03
' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   inventory_df.loc[mask, 'Demand Forecast'] = inventory_df.loc[mask, 'Units Ordered'] * np.random.uniform(1.1, 1.5, size = mask.sum())
# C:\Users\neel9\AppData\Local\Temp\ipykernel_2612\3499703856.py:31: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   inventory_df = inventory_df.groupby('Product ID', group_keys=False).apply(update_inventory).reset_index(drop=True)
#            Date  Product ID                             Product Name  \
# 0    2017-04-01          19  Nike Men's Fingertrap Max Training Shoe
# 1    2017-05-01          19  Nike Men's Fingertrap Max Training Shoe
# 2    2017-06-01          19  Nike Men's Fingertrap Max Training Shoe
# 3    2017-07-01          19  Nike Men's Fingertrap Max Training Shoe
# 4    2017-08-01          19  Nike Men's Fingertrap Max Training Shoe
# ...         ...         ...                                      ...
# 2445 2018-01-01        1361                                    Toys
# 2446 2017-12-01        1362                     Fighting video games
# 2447 2018-01-01        1362                     Fighting video games
# 2448 2017-12-01        1363                           Summer dresses
# 2449 2018-01-01        1363                           Summer dresses
#
#       Department Id  Category Id     Category Name  Inventory Level  \
# 0                 2            2            Soccer              3.0
# 1                 2            2            Soccer             18.0
# 2                 2            2            Soccer             24.0
# 3                 2            2            Soccer             29.0
# 4                 2            2            Soccer             36.0
# ...             ...          ...               ...              ...
# 2445              7           74              Toys            295.0
# 2446              9           75       Video Games            250.0
# 2447              9           75       Video Games            761.0
# 2448              4           76  Women's Clothing            333.0
# 2449              4           76  Women's Clothing            503.0
#
#       Total Units Sold   Total Sales  Total Profit  Units Ordered  \
# 0                  2.0    249.979996    106.320000            2.0
# 1                 13.0   1624.869973    228.510005           13.0
# 2                 13.0   1624.869973    458.999994           13.0
# 3                 15.0   1874.849969    325.769995           15.0
# 4                 17.0   2124.829964   -194.960013           17.0
# ...                ...           ...           ...            ...
# 2445             276.0   3185.039989    443.520002          226.0
# 2446             228.0   9063.000000    750.370007          219.0
# 2447             610.0  24247.500000   1967.149990          565.0
# 2448             272.0  58703.041986   7927.739958          280.0
# 2449             378.0  81579.962759  11175.109972          324.0
#
#       Demand Forecast  Product Price  Competitor Pricing  Cost to Company  \
# 0                 3.0     124.989998              131.84            91.43
# 1                17.0     124.989998              123.46            93.00
# 2                19.0     124.989998              133.95            91.03
# 3                18.0     124.989998              129.92            94.75
# 4                22.0     124.989998              114.85            90.61
# ...               ...            ...                 ...              ...
# 2445            253.0      11.540000               11.71             8.03
# 2446            250.0      39.750000               36.17            25.61
# 2447            739.0      39.750000               38.99            27.88
# 2448            333.0     215.820007              219.40           167.86
# 2449            442.0     215.820007              219.50           163.69
#
#       Total Inventory  month  quarter  is_month_start  is_month_end
# 0                 1.0      4        2            True         False
# 1                 5.0      5        2            True         False
# 2                11.0      6        2            True         False
# 3                14.0      7        3            True         False
# 4                19.0      8        3            True         False
# ...               ...    ...      ...             ...           ...
# 2445             19.0      1        1            True         False
# 2446             22.0     12        4            True         False
# 2447            151.0      1        1            True         False
# 2448             61.0     12        4            True         False
# 2449            125.0      1        1            True         False
#
# [2450 rows x 20 columns]

# %%
inventory_df = inventory_df[inventory_df['Date'] <= '2017-04-30']
inventory_df.rename(columns = {"Demand Forecast": "Inventory Forecast"}, inplace = True)
inventory_df.reset_index(drop = True)
# Out:
# C:\Users\neel9\AppData\Local\Temp\ipykernel_2612\280946684.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inventory_df.rename(columns = {"Demand Forecast": "Inventory Forecast"}, inplace = True)
#            Date  Product ID                             Product Name  \
# 0    2017-04-01          19  Nike Men's Fingertrap Max Training Shoe
# 1    2017-04-01          24              Elevation Training Mask 2.0
# 2    2017-04-01          35  adidas Brazuca 2014 Official Match Ball
# 3    2015-01-01          37    adidas Kids' F5 Messi FG Soccer Cleat
# 4    2015-02-01          37    adidas Kids' F5 Messi FG Soccer Cleat
# ...         ...         ...                                      ...
# 1540 2016-12-01        1073              Pelican Sunstream 100 Kayak
# 1541 2017-01-01        1073              Pelican Sunstream 100 Kayak
# 1542 2017-02-01        1073              Pelican Sunstream 100 Kayak
# 1543 2017-03-01        1073              Pelican Sunstream 100 Kayak
# 1544 2017-04-01        1073              Pelican Sunstream 100 Kayak
#
#       Department Id  Category Id        Category Name  Inventory Level  \
# 0                 2            2               Soccer              3.0
# 1                 2            2               Soccer             16.0
# 2                 2            3  Baseball & Softball              7.0
# 3                 2            3  Baseball & Softball             26.0
# 4                 2            3  Baseball & Softball             26.0
# ...             ...          ...                  ...              ...
# 1540              7           48         Water Sports           2505.0
# 1541              7           48         Water Sports           2526.0
# 1542              7           48         Water Sports           2540.0
# 1543              7           48         Water Sports           2731.0
# 1544              7           48         Water Sports           2853.0
#
#       Total Units Sold   Total Sales  Total Profit  Units Ordered  \
# 0                  2.0    249.979996    106.320000            2.0
# 1                 12.0    959.879982    -90.479999           11.0
# 2                  5.0    799.950028    122.730002            5.0
# 3                 18.0    629.820015   -305.269996           18.0
# 4                 20.0    699.800022    174.660004           17.0
# ...                ...           ...           ...            ...
# 1540             446.0  89195.542453  12422.839960          446.0
# 1541             432.0  86395.682376   9042.300007          432.0
# 1542             443.0  88595.572436  12089.199881          443.0
# 1543             495.0  98995.052722  10440.139997          495.0
# 1544             481.0  96195.192645   9400.380019          481.0
#
#       Inventory Forecast  Product Price  Competitor Pricing  Cost to Company  \
# 0                    3.0     124.989998              131.84            91.43
# 1                   16.0      79.989998               77.92            61.96
# 2                    7.0     159.990005              168.25           110.27
# 3                   26.0      34.990002               36.70            24.53
# 4                   18.0      34.990002               38.26            22.64
# ...                  ...            ...                 ...              ...
# 1540               483.0     199.990005              207.74           156.35
# 1541               467.0     199.990005              213.90           143.74
# 1542               446.0     199.990005              189.49           131.97
# 1543               634.0     199.990005              186.01           147.28
# 1544               617.0     199.990005              180.34           149.60
#
#       Total Inventory  month  quarter  is_month_start  is_month_end
# 0                 1.0      4        2            True         False
# 1                 4.0      4        2            True         False
# 2                 2.0      4        2            True         False
# 3                 8.0      1        1            True         False
# 4                 6.0      2        1            True         False
# ...               ...    ...      ...             ...           ...
# 1540           2059.0     12        4            True         False
# 1541           2094.0      1        1            True         False
# 1542           2097.0      2        1            True         False
# 1543           2236.0      3        1            True         False
# 1544           2372.0      4        2            True         False
#
# [1545 rows x 20 columns]

# %%
inventory_df.to_csv('inventory_final.csv', index = False)
